# %%
import pandas as pd
import sqlite3

#1 - IMPORTANDO DADOS DIRETAMENTE DO BANCO DE DADOS COM PANDAS
con = sqlite3.connect("../db.sqlite3")
df = pd.read_sql_query("SELECT * from relatorios_tableactionmodel", con)

print(df.columns.to_list())
display(df)
# Out:
# ['id', 'acao_realizada', 'tecnico_presencial', 'tecnico_nao_presencial', 'outras_acoes', 'numbers_employee', 'date_actions', 'date_to_publication', 'user_id', 'description_action']
#    id                       acao_realizada          tecnico_presencial  \
# 0   1       Apoio Técnico Presencial (ATP)  Encontros de apoio técnico
# 1   2  Apoio Técnico Não Presencial (ATNP)             (Não se aplica)
#
#              tecnico_nao_presencial     outras_acoes  numbers_employee  \
# 0                   (Não se Aplica)  (Não se aplica)                12
# 1  E-mails, telefonemas e mensagens  (Não se aplica)                 1
#
#   date_actions date_to_publication  user_id  \
# 0   2022-07-18          2022-07-18        1
# 1   2022-07-18          2022-07-18        1
#
#                                   description_action
# 0  Lorem Ipsum é simplesmente uma simulação de te...
# 1  Lorem Ipsum é simplesmente uma simulação de te...

# %%
listMun = pd.read_csv(r'C:\Users\roversoncosta\Desktop\MT_Municípios.txt', encoding='latin-1', sep=',')
for item in listMun.Municipios.tolist():
    print((item,item),",")
# Out:
# ('Acorizal', 'Acorizal') ,
# ('Água Boa', 'Água Boa') ,
# ('Alta Floresta', 'Alta Floresta') ,
# ('Alto Araguaia', 'Alto Araguaia') ,
# ('Alto Boa Vista', 'Alto Boa Vista') ,
# ('Alto Garças', 'Alto Garças') ,
# ('Alto Paraguai', 'Alto Paraguai') ,
# ('Alto Taquari', 'Alto Taquari') ,
# ('Apiacás', 'Apiacás') ,
# ('Araguaiana', 'Araguaiana') ,
# ('Araguainha', 'Araguainha') ,
# ('Araputanga', 'Araputanga') ,
# ('Arenápolis', 'Arenápolis') ,
# ('Aripuanã', 'Aripuanã') ,
# ('Barão de Melgaço', 'Barão de Melgaço') ,
# ('Barra do Bugres', 'Barra do Bugres') ,
# ('Barra do Garças', 'Barra do Garças') ,
# ('Bom Jesus do Araguaia', 'Bom Jesus do Araguaia') ,
# ('Brasnorte', 'Brasnorte') ,
# ('Cáceres', 'Cáceres') ,
# ('Campinápolis', 'Campinápolis') ,
# ('Campo Novo do Parecis', 'Campo Novo do Parecis') ,
# ('Campo Verde', 'Campo Verde') ,
# ('Campos de Júlio', 'Campos de Júlio') ,
# ('Canabrava do Norte', 'Canabrava do Norte') ,
# ('Canarana', 'Canarana') ,
# ('Carlinda', 'Carlinda') ,
# ...
